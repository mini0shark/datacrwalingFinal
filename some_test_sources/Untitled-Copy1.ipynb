# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

# %%
names = ['Date', 'Acid/Fusion/POP', '드라마OST', '클래식', 'Indie_Music', '영화OST', 'Ballad', 'Dance', 'Rock/Metal',
         'R&B/Soul', 'Electronica', 'Rap/HipHop', 'EDM', 'POP', 'J-POP', '성인가요', '재즈', 'NewAge',
         'Fork/Bules', '만화/게임OST', '-']

# %%
target_genre = ['Ballad', 'Dance', 'Rock/Metal', 'R&B/Soul', 'Rap/HipHop', 'Fork/Bules', 'Indie_Music', 'POP', 'Electronica']

# %%
def get_data_frame():
    # print("current : ", year, month)
    load_file = "C:/Users/jay/Jay/기말플젝/final_data/final.csv"

    try:
        data = pd.read_csv(load_file, encoding='cp949',
                           names=names, header=None)
    except UnicodeError:
        try:
            data = pd.read_csv(load_file, encoding='utf-8',
                               names=names, header=None)
        except Exception as e:
            print(e)
    return data

# %%
def get_yearly_data(result, year, data, keys):
    start_month = (year - 2000) * 12
    end_month = start_month + 12 if year != 2019 else start_month + 11
    for i in range(start_month, end_month):
        row = []
        for key in keys:
            if key == 'Date':
                data.get(key)[i] = "2000-"+data.get(key)[i].split("-")[1]
            row.append(data.get(key)[i])
            # print(data.get(key)[i])
        result.append(row)

# %%
def get_monthly_data(result, year):
    monthly_df = pd.DataFrame(result, columns=names)
    monthly_df['Date'] = pd.to_datetime(monthly_df['Date'], dayfirst=True, errors='coerce')
    monthly_df = monthly_df.set_index('Date')
    return monthly_df

# %%
def get_analysis(st_year, end_year, key):
    data = get_data_frame()
    elements = data.keys()
    data_list =[]
    for year in range(st_year, end_year):
        result = []
        get_yearly_data(result, year, data, elements)
        data_list.append(get_monthly_data(result, year))
    # for key in target_genre:
    drop_list = []
    for genre in names:
        if genre != key and genre != 'Date':
            drop_list.append(genre)
    for df in data_list:
        monthly_df = df
        monthly_df = monthly_df.drop(drop_list, axis=1, inplace=False)
        monthly_df[key] = pd.to_numeric(monthly_df[key], errors='coerce')
        monthly_open = monthly_df[key].plot(title="%d\'s Record For %s"%(year, key))
        fig = monthly_open.get_figure()
        fig.set_size_inches(50, 10)
    fig.show()

# %%
get_analysis(2000, 2020, 'Ballad')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Dance')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Rock/Metal')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'R&B/Soul')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Rap/HipHop')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Fork/Bules')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Indie_Music')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'POP')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
get_analysis(2000, 2020, 'Electronica')
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
